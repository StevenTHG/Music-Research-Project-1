# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
music_df = pd.read_csv('../Music-Research-Project-1/Resources/top10s.csv', encoding = 'ISO-8859-1')
music_df.head(10)
# Out:
#    Unnamed: 0                                       title         artist  \
# 0           1                            Hey, Soul Sister          Train
# 1           2                        Love The Way You Lie         Eminem
# 2           3                                     TiK ToK          Kesha
# 3           4                                 Bad Romance      Lady Gaga
# 4           5                        Just the Way You Are     Bruno Mars
# 5           6                                        Baby  Justin Bieber
# 6           7                                    Dynamite      Taio Cruz
# 7           8                                     Secrets    OneRepublic
# 8           9  Empire State of Mind (Part II) Broken Down    Alicia Keys
# 9          10                    Only Girl (In The World)        Rihanna
#
#          top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# 0       neo mellow  2010   97    89    67  -4     8   80  217     19     4
# 1  detroit hip hop  2010   87    93    75  -5    52   64  263     24    23
# 2        dance pop  2010  120    84    76  -3    29   71  200     10    14
# 3        dance pop  2010  119    92    70  -4     8   71  295      0     4
# 4              pop  2010  109    84    64  -5     9   43  221      2     4
# 5     canadian pop  2010   65    86    73  -5    11   54  214      4    14
# 6        dance pop  2010  120    78    75  -4     4   82  203      0     9
# 7        dance pop  2010  148    76    52  -6    12   38  225      7     4
# 8          hip pop  2010   93    37    48  -8    12   14  216     74     3
# 9    barbadian pop  2010  126    72    79  -4     7   61  235     13     4
#
#    pop
# 0   83
# 1   82
# 2   80
# 3   79
# 4   78
# 5   77
# 6   77
# 7   77
# 8   76
# 9   73

# %%
music_df['top genre'] = music_df['top genre'].replace(['dance pop','canadian pop','barbadian pop',
                                                       'australian pop','indie pop','art pop','colombian pop',
                                                      'acoustic pop','baroque pop','candy pop','folk-pop','colombian pop',
                                                      'danish pop','moroccan pop',
                                                       'boy band','permanent wave','metropopolis','escape room',
                                                      'french indie pop'],'pop')

music_df['top genre'] = music_df['top genre'].replace(['detroit hip hop','atl hip hop','chicago rap',
                                                      'canadian hip hop','australian hip hop','hip hop','hip pop'],'hip hop')

music_df['top genre'] = music_df['top genre'].replace(['big room','house','australian dance','tropical house',
                                                      'belgian edm','electronic trap','electro house',
                                                       'brostep','electropop','escape room','electro',
                                                       'complextro','downtempo'],'edm')

music_df['top genre'] = music_df['top genre'].replace(['neo mellow','alaska indie','celtic rock','hollywood','latin','canadian latin',
                                                      'contemporary country','irish singer-songwriter',
                                                      'british soul'],'rock/country/other')
                                                      
music_df['top genre'] = music_df['top genre'].replace(['canadian contemporary r&b','alternative r&b'],'R&B')
music_df
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist           top genre  year  bpm  nrgy  dnce  dB  live  \
# 0               Train  rock/country/other  2010   97    89    67  -4     8
# 1              Eminem             hip hop  2010   87    93    75  -5    52
# 2               Kesha                 pop  2010  120    84    76  -3    29
# 3           Lady Gaga                 pop  2010  119    92    70  -4     8
# 4          Bruno Mars                 pop  2010  109    84    64  -5     9
# ..                ...                 ...   ...  ...   ...   ...  ..   ...
# 598       Mark Ronson                 pop  2019  104    66    61  -7    20
# 599        Ed Sheeran                 pop  2019   95    79    75  -6     7
# 600         DJ Khaled                 pop  2019  136    76    53  -5     9
# 601       Mark Ronson                 pop  2019  114    79    60  -6    42
# 602  The Chainsmokers                 edm  2019  150    44    70  -9    13
#
#      val  dur  acous  spch  pop
# 0     80  217     19     4   83
# 1     64  263     24    23   82
# 2     71  200     10    14   80
# 3     71  295      0     4   79
# 4     43  221      2     4   78
# ..   ...  ...    ...   ...  ...
# 598   16  176      1     3   75
# 599   61  206     21    12   75
# 600   65  260      7    34   70
# 601   24  217      1     7   69
# 602   23  213      6     6   67
#
# [603 rows x 15 columns]

# %%
genre_val = music_df.groupby(['top genre'])['val'].mean()
genre_val_plot = genre_val.plot(kind = 'bar', x = 'year', y= 'val', xlabel = 'Year',ylabel ='Average Valence Level' )

# %%
genre_dnce = music_df.groupby(['top genre'])['dnce'].mean()
genre_dnce_plot = genre_dnce.plot(kind = 'bar', x = 'year', y= 'dnce', xlabel = 'Year',ylabel ='Average Danceability Level' )

# %%
genre_nrgy = music_df.groupby(['top genre'])['nrgy'].mean()
genre_nrgy_plot = genre_nrgy.plot(kind = 'bar', x = 'year', y= 'nrgy', xlabel = 'Year',ylabel ='Average Energy Level' )

# %%
genre_spch = music_df.groupby(['top genre'])['spch'].mean()
genre_spch_plot = genre_spch.plot(kind = 'bar', x = 'year', y= 'spch', xlabel = 'Year',ylabel ='Average Speechiness Level' )

# %%
genre_acous = music_df.groupby(['top genre'])['acous'].mean()
genre_acous_plot = genre_acous.plot(kind = 'bar', x = 'year', y= 'acous', xlabel = 'Year',ylabel ='Average Acoustic Level' )

# %%
genre_mean = music_df.groupby(['top genre'])['acous','val','spch','nrgy','dnce'].mean()
genre_mean
#bar1 = genre_mean.plot(kind = 'bar')
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_22904\550190291.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   genre_mean = music_df.groupby(['top genre'])['acous','val','spch','nrgy','dnce'].mean()
#                         acous        val       spch       nrgy       dnce
# top genre
# R&B                 15.000000  34.200000  13.400000  62.300000  58.100000
# edm                 12.200000  45.618182   7.109091  71.145455  61.163636
# hip hop             17.571429  37.142857  13.857143  67.523810  65.714286
# pop                 13.104723  54.632444   8.379877  71.735113  65.344969
# rock/country/other  35.566667  41.833333   4.766667  54.166667  55.766667
