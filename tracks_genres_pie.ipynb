# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
music_df1 = pd.read_csv(
    '../Music-Research-Project-1/Resources/top10s.csv', encoding='ISO-8859-1')
music_df1.head(10)
# Out:
#    Unnamed: 0                                       title         artist  \
# 0           1                            Hey, Soul Sister          Train
# 1           2                        Love The Way You Lie         Eminem
# 2           3                                     TiK ToK          Kesha
# 3           4                                 Bad Romance      Lady Gaga
# 4           5                        Just the Way You Are     Bruno Mars
# 5           6                                        Baby  Justin Bieber
# 6           7                                    Dynamite      Taio Cruz
# 7           8                                     Secrets    OneRepublic
# 8           9  Empire State of Mind (Part II) Broken Down    Alicia Keys
# 9          10                    Only Girl (In The World)        Rihanna
#
#          top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# 0       neo mellow  2010   97    89    67  -4     8   80  217     19     4
# ...

# %%
music_genre_df1 = music_df1['top genre'].unique()
music_genre_df1
# Out:
# array(['neo mellow', 'detroit hip hop', 'dance pop', 'pop',
#        'canadian pop', 'hip pop', 'barbadian pop', 'atl hip hop',
#        'australian pop', 'indie pop', 'art pop', 'colombian pop',
#        'big room', 'british soul', 'chicago rap', 'acoustic pop',
#        'permanent wave', 'boy band', 'baroque pop', 'celtic rock',
#        'electro', 'complextro', 'canadian hip hop', 'candy pop',
#        'alaska indie', 'folk-pop', 'metropopolis', 'house',
#        'australian hip hop', 'electropop', 'australian dance',
#        'hollywood', 'canadian contemporary r&b',
#        'irish singer-songwriter', 'tropical house', 'belgian edm',
#        'french indie pop', 'hip hop', 'danish pop', 'latin',
#        'canadian latin', 'electronic trap', 'edm', 'electro house',
#        'downtempo', 'brostep', 'contemporary country', 'moroccan pop',
#        'escape room', 'alternative r&b'], dtype=object)

# %%
music_df1['top genre'] = music_df1['top genre'].replace(['dance pop', 'canadian pop', 'barbadian pop',
                                                       'australian pop', 'indie pop', 'art pop', 'colombian pop',
                                                      'acoustic pop', 'baroque pop', 'candy pop', 'folk-pop', 'colombian pop',
                                                       'danish pop', 'moroccan pop',
                                                       'boy band', 'permanent wave', 'metropopolis', 'escape room',
                                                       'french indie pop'], 'pop')

music_df1['top genre'] = music_df1['top genre'].replace(['detroit hip hop', 'atl hip hop', 'chicago rap',
                                                      'canadian hip hop', 'australian hip hop', 'hip hop', 'hip pop'], 'hip hop')

music_df1['top genre'] = music_df1['top genre'].replace(['big room', 'house', 'australian dance', 'tropical house',
                                                      'belgian edm', 'electronic trap', 'electro house',
                                                       'brostep', 'electropop', 'escape room', 'electro',
                                                       'complextro', 'downtempo'], 'edm')

music_df1['top genre'] = music_df1['top genre'].replace(['neo mellow', 'alaska indie', 'celtic rock', 'hollywood', 'latin', 'canadian latin',
                                                      'contemporary country', 'irish singer-songwriter',
                                                       'british soul'], 'rock/country/other')

music_df1['top genre'] = music_df1['top genre'].replace(
    ['canadian contemporary r&b', 'alternative r&b'], 'R&B')
music_df1
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist           top genre  year  bpm  nrgy  dnce  dB  live  \
# 0               Train  rock/country/other  2010   97    89    67  -4     8
# ...

# %%
music_genre_df1 = music_df1['top genre'].unique()
music_genre_df1
# Out:
# array(['rock/country/other', 'hip hop', 'pop', 'edm', 'R&B'], dtype=object)

# %%
pop_df1 = music_df1[['top genre', 'year']].value_counts()
pop_df1.head(10)
# Out:
# top genre  year
# pop        2015    79
#            2013    61
#            2016    59
#            2018    54
#            2011    49
#            2014    44
#            2017    44
#            2010    42
#            2012    34
#            2019    21
# dtype: int64

# %%
pop_2011_df = music_df1.loc[(music_df1['top genre'] == 'pop') & (music_df1['year'] == 2011)]
pop_2011_df
# Out:
#      Unnamed: 0                                              title  \
# 51           52                                   A Thousand Years
# 53           54                                 Give Me Everything
# 54           55                               Just the Way You Are
# 56           57                              Run the World (Girls)
# 57           58  Moves Like Jagger - Studio Recording From The ...
# 58           59                                        Love On Top
# 59           60                                            Grenade
# 60           61                                    Tonight Tonight
# 61           62                                      What the Hell
# 62           63                                      Born This Way
# 64           65                                          Marry You
# 65           66                             Best Thing I Never Had
# 66           67                                  Party Rock Anthem
# ...

# %%
# 2011 Top 10 Breakdown by Genres & Pie Chart Plot

# %%
pop_2011_df = music_df1.loc[(music_df1['top genre']=='pop') & (music_df1['year']== 2011)]
len(pop_2011_df)
# Out:
# 49

# %%
rco_2011_df = music_df1.loc[(music_df1['top genre'] =='rock/country/other') & (music_df1['year'] == 2011)]
len(rco_2011_df)
# Out:
# 2

# %%
hip_hop_2011_df = music_df1.loc[(music_df1['top genre'] == 'hip hop') & (music_df1['year'] == 2011)]
len(hip_hop_2011_df)
# Out:
# 2

# %%
edm_2011_df = music_df1.loc[(music_df1['top genre'] == 'edm') & (music_df1['year'] == 2011)]
len(edm_2011_df)
# Out:
# 0

# %%
rb_2011_df = music_df1.loc[(music_df1['top genre'] == 'r&b') & (music_df1['year'] == 2011)]
len(rb_2011_df)
# Out:
# 0

# %%
# Labels for the sections of our pie chart
labels = ['pop', 'rock/country/other', 'hip hop', 'edm', 'r&b']
# The values of each section of the pie chart
sizes = [49, 2, 2, 0, 0]

# The colors of each section of the pie chart
colors = ['red', 'orange', 'lightcoral', 'lightskyblue',  'green']
# Tells matplotlib to separate the "pop" section from the others
explode = (0, 0.1, 0.03, 0, 0.3)

# %%
# Create a pie chart based upon the values above
# Automatically find the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x21566371910>,
# ...
#  [Text(0.6529940000717391, -0.8852111815099885, 'pop'),
#   Text(-0.5931425048945785, 1.0431596085390697, 'rock/country/other'),
#   Text(-0.7736467262883502, 0.8236326504597291, 'hip hop'),
#   Text(-0.8426488874308751, 0.7070663706551945, 'edm'),
#   Text(-1.0724622203665684, 0.8999026535611566, 'r&b')],
#  [Text(0.3561785454936759, -0.48284246264181185, '92.5%'),
#   Text(-0.3459997945218375, 0.6085097716477905, '3.8%'),
#   Text(-0.4313251659837704, 0.4591934245925923, '3.8%'),
#   Text(-0.45962666587138634, 0.3856725658119242, '0.0%'),
#   Text(-0.6894399988070795, 0.5785088487178863, '0.0%')])

# %%
# 2015 Top 10 Breakdown by Genres & Pie Chart Plot

# %%
pop_2015_df = music_df1.loc[(music_df1['top genre'] == 'pop') & (music_df1['year'] == 2015)]
len(pop_2015_df)
# Out:
# 79

# %%
rco_2015_df = music_df1.loc[(music_df1['top genre'] == 'rock/country/other') & (music_df1['year'] == 2015)]
len(rco_2015_df)
# Out:
# 3

# %%
hip_hop_2015_df = music_df1.loc[(music_df1['top genre'] == 'hip hop') & (music_df1['year'] == 2015)]
len(hip_hop_2015_df)
# Out:
# 2

# %%
edm_2015_df = music_df1.loc[(music_df1['top genre'] == 'edm') & (music_df1['year'] == 2015)]
len(edm_2015_df)
# Out:
# 8

# %%
rb_2015_df = music_df1.loc[(music_df1['top genre'] == 'r&b') & (music_df1['year'] == 2015)]
len(rb_2015_df)
# Out:
# 0

# %%
# Labels for the sections of our pie chart
labels = ['pop', 'rock/country/other', 'hip hop', 'edm', 'r&b']

# The values of each section of the pie chart
sizes = [79, 3, 2, 8, 0]

# The colors of each section of the pie chart
colors = ['red', 'orange', 'lightcoral', 'lightskyblue',  'green']

# Tells matplotlib to separate the "pop" section from the others
explode = (0.1, 0.1, 0, 0, 0)

# %%
# Create a pie chart based upon the values above
# Automatically find the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x21567691dc0>,
# ...
#  [Text(0.4988744047529814, -1.0913864248204477, 'pop'),
#   Text(-0.10458669542918189, 1.1954336548463087, 'rock/country/other'),
#   Text(-0.28066733502833463, 1.0635910149338856, 'hip hop'),
#   Text(-0.6206368142785939, 0.9081904782379732, 'edm'),
#   Text(-0.8426487798553269, 0.7070664988587204, 'r&b')],
#  [Text(0.2910100694392391, -0.6366420811452611, '85.9%'),
#   Text(-0.061008905667022766, 0.6973362986603467, '3.3%'),
#   Text(-0.15309127365181888, 0.5801405536003011, '2.2%'),
#   Text(-0.3385291714246875, 0.49537662449343983, '8.7%'),
#   Text(-0.45962660719381465, 0.38567263574112015, '0.0%')])

# %%
# 2019 Top 10 Breakdown by Genres & Pie Chart Plot

# %%
pop_2019_df = music_df1.loc[(music_df1['top genre'] == 'pop') & (music_df1['year'] == 2019)]
len(pop_2019_df)
# Out:
# 21

# %%
rco_2019_df = music_df1.loc[(music_df1['top genre'] == 'rock/country/other') & (music_df1['year'] == 2019)]
len(rco_2019_df)
# Out:
# 1

# %%
hip_hop_2019_df = music_df1.loc[(music_df1['top genre'] == 'hip hop') & (music_df1['year'] == 2019)]
len(hip_hop_2019_df)
# Out:
# 0

# %%
edm_2019_df = music_df1.loc[(music_df1['top genre'] == 'edm') & (music_df1['year'] == 2019)]
len(edm_2019_df)
# Out:
# 8

# %%
rb_2019_df = music_df1.loc[(music_df1['top genre'] == 'r&b') & (music_df1['year'] == 2019)]
len(rb_2019_df)
# Out:
# 0

# %%
# Labels for the sections of our pie chart
labels = ['pop', 'rock/country/other', 'hip hop', 'edm', 'r&b']

# The values of each section of the pie chart
sizes = [21, 1, 0, 8, 0]

# The colors of each section of the pie chart
colors = ['red', 'orange', 'lightcoral', 'lightskyblue',  'green']

# Tells matplotlib to separate the "pop" section from the others
explode = (0.1, 0, 0.1, 0, 0)

# %%
# Create a pie chart based upon the values above
# Automatically find the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x215663dac10>,
# ...
#  [Text(-0.08370781332432059, -1.1970768571768735, 'pop'),
#   Text(0.8668118759939737, 0.677227562666943, 'rock/country/other'),
#   Text(0.8632078137380411, 0.833589989324243, 'hip hop'),
#   Text(-0.03838942407196686, 1.0993299104997658, 'edm'),
#   Text(-0.842648903980958, 0.707066350931573, 'r&b')],
#  [Text(-0.048829557772520335, -0.6982948333531762, '70.0%'),
#   Text(0.4728064778148947, 0.369396852363787, '3.3%'),
#   Text(0.5035378913471906, 0.4862608271058084, '0.0%'),
#   Text(-0.020939685857436465, 0.5996344966362358, '26.7%'),
#   Text(-0.45962667489870435, 0.3856725550535853, '0.0%')])
