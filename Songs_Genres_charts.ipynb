# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
music_df = pd.read_csv('../Music-Research-Project-1/Resources/top10s.csv', encoding = 'ISO-8859-1')
music_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 import scipy.stats as st
# ----> 4 music_df = pd.read_csv('../Music-Research-Project-1/Resources/top10s.csv', encoding = 'ISO-8859-1')
#       5 music_df.head(10)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
music_genre_df = music_df['top genre'].unique()
music_genre_df
# Out:
# array(['neo mellow', 'detroit hip hop', 'dance pop', 'pop',
#        'canadian pop', 'hip pop', 'barbadian pop', 'atl hip hop',
#        'australian pop', 'indie pop', 'art pop', 'colombian pop',
#        'big room', 'british soul', 'chicago rap', 'acoustic pop',
#        'permanent wave', 'boy band', 'baroque pop', 'celtic rock',
#        'electro', 'complextro', 'canadian hip hop', 'candy pop',
#        'alaska indie', 'folk-pop', 'metropopolis', 'house',
#        'australian hip hop', 'electropop', 'australian dance',
#        'hollywood', 'canadian contemporary r&b',
#        'irish singer-songwriter', 'tropical house', 'belgian edm',
#        'french indie pop', 'hip hop', 'danish pop', 'latin',
#        'canadian latin', 'electronic trap', 'edm', 'electro house',
#        'downtempo', 'brostep', 'contemporary country', 'moroccan pop',
#        'escape room', 'alternative r&b'], dtype=object)

# %%
music_df['top genre'] = music_df['top genre'].replace(['dance pop','canadian pop','barbadian pop',
                                                       'australian pop','indie pop','art pop','colombian pop',
                                                      'acoustic pop','baroque pop','candy pop','folk-pop','colombian pop',
                                                      'danish pop','moroccan pop',
                                                       'boy band','permanent wave','metropopolis','escape room',
                                                      'french indie pop'],'pop')

music_df['top genre'] = music_df['top genre'].replace(['detroit hip hop','atl hip hop','chicago rap',
                                                      'canadian hip hop','australian hip hop','hip hop','hip pop'],'hip hop')

music_df['top genre'] = music_df['top genre'].replace(['big room','house','australian dance','tropical house',
                                                      'belgian edm','electronic trap','electro house',
                                                       'brostep','electropop','escape room','electro',
                                                       'complextro','downtempo'],'edm')

music_df['top genre'] = music_df['top genre'].replace(['neo mellow','alaska indie','celtic rock','hollywood','latin','canadian latin',
                                                      'contemporary country','irish singer-songwriter',
                                                      'british soul'],'rock/country/other')
                                                      
music_df['top genre'] = music_df['top genre'].replace(['canadian contemporary r&b','alternative r&b'],'R&B')
music_df
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist           top genre  year  bpm  nrgy  dnce  dB  live  \
# 0               Train  rock/country/other  2010   97    89    67  -4     8
# ...

# %%
music_genre_df = music_df['top genre'].unique()
music_genre_df
# Out:
# array(['rock/country/other', 'hip hop', 'pop', 'edm', 'R&B'], dtype=object)

# %%
pop_df = music_df['top genre'].value_counts()
pop_df
# Out:
# pop                   487
# edm                    55
# rock/country/other     30
# hip hop                21
# R&B                    10
# Name: top genre, dtype: int64

# %%
genre1_df = music_df[music_df['top genre'] == 'rock/country/other']
genre1_df
# Out:
#      Unnamed: 0                             title             artist  \
# 0             1                  Hey, Soul Sister              Train
# 52           53                  Someone Like You              Adele
# 55           56               Rolling in the Deep              Adele
# 112         113              Set Fire to the Rain              Adele
# 143         144                      Hall of Fame         The Script
# 207         208                     Foolish Games              Jewel
# 210         211                         All of Me        John Legend
# 246         247                             Wings              Birdy
# 249         250                     Say Something  A Great Big World
# 255         256                  Not About Angels              Birdy
# 260         261    Tee Shirt - Soundtrack Version              Birdy
# 261         262                  Words as Weapons              Birdy
# 264         265                        Cannonball        Lea Michele
# ...

# %%
year_spch = music_df.groupby(['year'])['spch'].mean()
year_spch_plot = year_spch.plot(kind = 'bar', x = 'year', y= 'spch', xlabel = 'Year',ylabel ='Average Speech Level' )

# %%
year_dB = music_df.groupby(['year'])['dB'].mean()
year_spch_plot = year_dB.plot(kind = 'bar', x = 'year', y= 'dB', xlabel = 'Year',ylabel ='Average Decibel Level' )

# %%
year_live = music_df.groupby(['year'])['live'].mean()
year_live_plot = year_live.plot(kind = 'bar', x = 'year', y= 'live', xlabel = 'Year',ylabel ='Average Liveliness' )

# %%
year_val = music_df.groupby(['year'])['val'].mean()
year_val_plot = year_val.plot(kind = 'bar', x = 'year', y= 'val', xlabel = 'Year',ylabel ='Average Valence Level' )

# %%
genre_val = music_df.groupby(['top genre'])['val'].mean()
genre_val_plot = year_val.plot(kind = 'bar', x = 'year', y= 'val', xlabel = 'Year',ylabel ='Average Valence Level' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 genre_val = music_df.groupby(['top genre'])['val'].mean()
#       2 genre_val_plot = year_val.plot(kind = 'bar', x = 'year', y= 'val', xlabel = 'Year',ylabel ='Average Valence Level' )
#
# NameError: name 'music_df' is not defined

# %%
year_acous = music_df.groupby(['year'])['acous'].mean()
year_acous_plot = year_acous.plot(kind = 'bar', x = 'year', y= 'acous', xlabel = 'Year',ylabel ='Average Acoustic Level' )
year_acous = music_df.groupby(['year'])['acous'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 year_acous = music_df.groupby(['year'])['acous'].mean()
#       2 year_acous_plot = year_acous.plot(kind = 'bar', x = 'year', y= 'acous', xlabel = 'Year',ylabel ='Average Acoustic Level' )
#       3 year_acous = music_df.groupby(['year'])['acous'].mean()
#
# NameError: name 'music_df' is not defined

# %%
year_genre = music_df.groupby(['year'])['top genre'].value_counts()
df = pd.DataFrame({'pop':[42,49,34,61,44,79,59,44,54,21],
                   'hip hop':[7,2,0,3,2,2,2,0,0,3],
                   'edm':[1,0,0,5,5,8,8,15,5,8],
                   'rock/country/other':[1,2,1,2,7,3,8,3,2,1],
                   'R&B':[0,0,0,0,0,3,3,3,0,1]},index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019])

line_plot = df.plot.line()
plt.xlabel('Year')
plt.ylabel('Number of Top Songs')
# Out:
# Text(0, 0.5, 'Number of Top Songs')
